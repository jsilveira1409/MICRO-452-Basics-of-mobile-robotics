# %%
import numpy as np
import math
import time
from computer_vision import *
from dijkstra import *
from kalman import *
from test import *

# %%
from tdmclient import ClientAsync,aw
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()
# Out:
# Node 2c7350d0-9e66-4eb8-9b25-c07ee89089f8

# %%
path = [[100,0], [100,100],[0, 100], [0,0]]
await motion_control(node, path)
await node.unlock()
# Out:
# c:\Users\osour\OneDrive - epfl.ch\EPFL\MA1\MICRO-452 Basics of mobile robotics\ MICRO-452 Basics of mobile robotics\test.py:88: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
